# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd /content/drive/MyDrive/colab_deploy
# Out:
# /content/drive/.shortcut-targets-by-id/1-ZjqWcvOJ5r2sdVpQPbQK4DyVuxxIoTr/colab_deploy

# %%
# !pip install -q transformers peft trl bitsandbytes datasets accelerate chromadb sentence-transformers openpyxl

# %%
# !python extract_rate_sheet_jsonl.py
# !python preprocessing_new.py
# Out:
# Reading Excel Sheet Index 1...
# SUCCESS: Extracted 36 records to preprocessed_data/rate_sheet_only.jsonl
# Skipping sheet: Main
# Skipping sheet: Rate Sheet July 1 2024
# Processing: LCA
# Processing: NAA
# Processing: NWA
# Processing: PWRA
# Processing: RDA
# Processing: VPCA
# Processing: VP-BA
# Processing: VPBA
# Processing: NSDA
# Processing: PLS
# Processing: CDA
# Processing: NMA
# Processing: NADA
# Processing: NADRA
# Processing: NUST4Car
# Processing: ESFCA
# Processing: NFDA
# Processing: NSA
# Processing: PF
# Processing: NMC
# Processing: NMF
# Processing: NSF
# Processing: NIF
# Processing: NUF
# Processing: NFMF
# Processing: NFBF
# Processing: PMYB &ALS
# Processing: NRF
# Processing: NHF
# Processing: Nust Life
# Processing: EFU Life
# Processing: Jubilee Life
# Processing: HOME REMITTANCE
# Skipping sheet: Sheet1
# Merging specialized rate sheet data from preprocessed_data/rate_sheet_only.jsonl...
#   Merged records. Total now: 339
#
# ✅ Finished. Extracted 339 Q&A pairs.
# Output saved to: preprocessed_data/bank_data_master.jsonl

# %%
# !python vector_db_setup.py
# Out:
# 📥 Loading embedding model: all-MiniLM-L6-v2...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 103/103 [00:00<00:00, 955.04it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#  Deleted existing collection 'bank_knowledge_base' for fresh start.
#  Reading records from preprocessed_data/bank_data_master.jsonl...
#  Indexing 339 records in batches of 500...
#  Indexed records 0 to 339
#
# ✅ Vector DB setup complete!
#   -> Total records stored: 339
#   -> Location: '/content/drive/.shortcut-targets-by-id/1-ZjqWcvOJ5r2sdVpQPbQK4DyVuxxIoTr/colab_deploy/vector_store_new'
#   -> You can now run rag_assistant.py

# %%
# !python finetune.py
# Out:
# GPU: Tesla T4
# VRAM: 15.6 GB
# Loading data...
# Loaded 354 Q&A pairs  (Excel: 339, Mobile: 15)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 662/662 [00:00<00:00, 3.33MB/s]
# tokenizer_config.json: 1.29kB [00:00, 3.98MB/s]
# vocab.json: 2.78MB [00:00, 75.6MB/s]
# merges.txt: 1.67MB [00:00, 126MB/s]
# tokenizer.json: 7.03MB [00:00, 113MB/s]
# Tokenizing: 100% 354/354 [00:00<00:00, 749.27 examples/s]
# Train: 318 samples  |  Eval: 36 samples
# Loading model...
# model.safetensors.index.json: 39.6kB [00:00, 108MB/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 100% 7.90G/7.90G [00:59<00:00, 161MB/s]
# Fetching 2 files: 100% 2/2 [00:59<00:00, 29.80s/it]
# Download complete: 100% 7.90G/7.90G [00:59<00:00, 132MB/s]
# Loading weights: 100% 483/483 [00:29<00:00, 16.27it/s, Materializing param=model.norm.weight]
# generation_config.json: 100% 206/206 [00:00<00:00, 941kB/s]
# trainable params: 31,293,440 || all params: 3,980,183,040 || trainable%: 0.7862
# Starting training...
# {'loss': '3.879', 'grad_norm': '2.085', 'learning_rate': '0.00018', 'epoch': '0.5031'}
# {'loss': '2.672', 'grad_norm': '1.262', 'learning_rate': '0.0001876', 'epoch': '1'}
#  33% 20/60 [07:36<14:58, 22.47s/it]
#   0% 0/5 [00:00<?, ?it/s]
#  40% 2/5 [00:02<00:03,  1.33s/it]
#  60% 3/5 [00:05<00:03,  1.88s/it]
#  80% 4/5 [00:07<00:02,  2.17s/it]
#
# {'eval_loss': '2.534', 'eval_runtime': '12.22', 'eval_samples_per_second': '2.945', 'eval_steps_per_second': '0.409', 'epoch': '1'}
#  33% 20/60 [07:49<14:58, 22.47s/it]
# 100% 5/5 [00:10<00:00,  2.05s/it]
#                                  /usr/local/lib/python3.12/dist-packages/peft/utils/save_and_load.py:309: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# {'loss': '2.131', 'grad_norm': '1.126', 'learning_rate': '0.0001426', 'epoch': '1.503'}
# {'loss': '1.795', 'grad_norm': '1.456', 'learning_rate': '8.126e-05', 'epoch': '2'}
#  67% 40/60 [16:29<07:33, 22.66s/it]
#   0% 0/5 [00:00<?, ?it/s]
#  40% 2/5 [00:02<00:03,  1.32s/it]
#  60% 3/5 [00:05<00:03,  1.88s/it]
#  80% 4/5 [00:07<00:02,  2.16s/it]
#
# {'eval_loss': '2.025', 'eval_runtime': '12.26', 'eval_samples_per_second': '2.936', 'eval_steps_per_second': '0.408', 'epoch': '2'}
#  67% 40/60 [16:42<07:33, 22.66s/it]
# 100% 5/5 [00:10<00:00,  2.07s/it]
#                                  /usr/local/lib/python3.12/dist-packages/peft/utils/save_and_load.py:309: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# {'loss': '1.529', 'grad_norm': '1.227', 'learning_rate': '2.71e-05', 'epoch': '2.503'}
# {'loss': '1.477', 'grad_norm': '1.565', 'learning_rate': '7.885e-07', 'epoch': '3'}
# 100% 60/60 [25:48<00:00, 22.67s/it]
#   0% 0/5 [00:00<?, ?it/s]
#  40% 2/5 [00:02<00:03,  1.32s/it]
#  60% 3/5 [00:05<00:03,  1.87s/it]
#  80% 4/5 [00:07<00:02,  2.16s/it]
#
# {'eval_loss': '1.921', 'eval_runtime': '12.2', 'eval_samples_per_second': '2.95', 'eval_steps_per_second': '0.41', 'epoch': '3'}
# 100% 60/60 [26:00<00:00, 22.67s/it]
# 100% 5/5 [00:10<00:00,  2.05s/it]
#                                  /usr/local/lib/python3.12/dist-packages/peft/utils/save_and_load.py:309: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# {'train_runtime': '1631', 'train_samples_per_second': '0.585', 'train_steps_per_second': '0.037', 'train_loss': '2.247', 'epoch': '3'}
# 100% 60/60 [27:11<00:00, 27.18s/it]
# /usr/local/lib/python3.12/dist-packages/peft/utils/save_and_load.py:309: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# LoRA adapter saved to '/content/lora_bank_model_qwen'
# Backing up model to Google Drive: /content/drive/MyDrive/colab_deploy/lora_bank_model_qwen...
# ✅ Successfully backed up your fine-tuned NUST Bank model to Drive!

# %%
# !python rag_assistant.py
# Out:
# 🚀 Initializing Bank RAG Assistant (Qwen-4B Smart Security)...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 103/103 [00:00<00:00, 1033.35it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Connected to Vector DB (339 records).
# 📦 Loading 4B Model: Qwen/Qwen1.5-4B-Chat...
# Loading weights: 100% 483/483 [00:26<00:00, 18.46it/s, Materializing param=model.norm.weight]
# 🔧 Aligning vocabulary to size 151647...
# ✨ Found LoRA Knowledge at /content/drive/MyDrive/colab_deploy/lora_bank_model_qwen. Enhancing NUST Bank Intelligence...
# Loading weights: 100% 105/105 [00:00<00:00, 746.56it/s, Materializing param=classifier.weight]
# BertForSequenceClassification LOAD REPORT from: cross-encoder/ms-marco-MiniLM-L-6-v2
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ⚙️ System Ready! Expert Advisor Persona & Memory Active.
#
# ============================================================
#  NUST Bank AI Support - Expert Mode (Smart Security)
# ============================================================
#
# 👤 User: hi
#
# 🤖 Assistant: Hello! How may I assist you today?
#
# ------------------------------------------------------------
#
# 👤 User: Can you tell the types of Accounts
# 🔍 Searching official bank records...
# 🤖 Assistant: NUST Asaan Digital Account - Current Account NUST Sahar Digital Account - Current/Saving Account NUST Freelancer Digital Account - Current/ Saving Account Little Champs Digital Account - Current/ Saving Account NUST Asaan Account - Current/ Saving Account
#
# ------------------------------------------------------------
#
# 👤 User: Gimme some driving skills recommendations
#
# 🤖 Assistant: I'm sorry, I am a specialized NUST Bank assistant and can only help with inquiries related to our accounts, loans, and interest rates. How can I help you with our banking services today?
# ------------------------------------------------------------
#
# 👤 User: object address  : 0x7b6b71eceec0
# object refcount : 3
# object type     : 0xa284e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr

# %%
# !pip install fastapi uvicorn pyngrok
# Out:
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (0.135.1)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (0.42.0)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.12/dist-packages (8.0.0)
# Requirement already satisfied: starlette>=0.46.0 in /usr/local/lib/python3.12/dist-packages (from fastapi) (0.52.1)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from fastapi) (2.12.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi) (0.0.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->fastapi) (2.41.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette>=0.46.0->fastapi) (4.12.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi) (3.11)

# %%
# !python api_service.py --token 3Bnzldsllzo22ZLaMrgUFo5xRdB_41DMsF8Ab3cZJgtKJZMjX
# Out:
# ==================================================
# YOUR ENDPOINT IS ALIVE!
# Tunnel URL: https://unsplendidly-postethmoid-tiffiny.ngrok-free.dev
# Copy/Paste this into the Streamlit Sidebar.
# ==================================================
#
# INFO:     Started server process [60451]
# INFO:     Waiting for application startup.
# 🚀 Powering up the Banking Brain (Qwen-4B)...
# Initializing Bank RAG Assistant (Qwen-4B Elite Advisor)...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 483/483 [00:24<00:00, 19.44it/s, Materializing param=model.norm.weight]
# Found LoRA Knowledge at /content/drive/MyDrive/colab_deploy/lora_bank_model_qwen. Enhancing Intelligence...
# Connected to Vector DB (339 records).
# Loading weights: 100% 103/103 [00:00<00:00, 1728.01it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights: 100% 105/105 [00:00<00:00, 723.30it/s, Materializing param=classifier.weight]
# BertForSequenceClassification LOAD REPORT from: cross-encoder/ms-marco-MiniLM-L-6-v2
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#  System Ready! Elite Advisor Active.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# Loading weights: 100% 103/103 [00:00<00:00, 1022.00it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# INFO:     175.107.255.38:0 - "POST /chat HTTP/1.1" 200 OK
# INFO:     175.107.255.38:0 - "POST /chat HTTP/1.1" 200 OK
# INFO:     175.107.255.38:0 - "POST /chat HTTP/1.1" 200 OK
# INFO:     175.107.255.38:0 - "POST /chat HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Finished server process [60451]
# ERROR:    Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/runners.py", line 195, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "uvloop/loop.pyx", line 1512, in uvloop.loop.Loop.run_until_complete
#   File "uvloop/loop.pyx", line 1505, in uvloop.loop.Loop.run_until_complete
#   File "uvloop/loop.pyx", line 1379, in uvloop.loop.Loop.run_forever
#   File "uvloop/loop.pyx", line 557, in uvloop.loop.Loop._run
#   File "uvloop/loop.pyx", line 476, in uvloop.loop.Loop._on_idle
#   File "uvloop/cbhandles.pyx", line 83, in uvloop.loop.Handle._run
#   File "uvloop/cbhandles.pyx", line 63, in uvloop.loop.Handle._run
#   File "/usr/local/lib/python3.12/dist-packages/uvicorn/server.py", line 78, in serve
#     with self.capture_signals():
#          ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/contextlib.py", line 144, in __exit__
#     next(self.gen)
#   File "/usr/local/lib/python3.12/dist-packages/uvicorn/server.py", line 339, in capture_signals
#     signal.raise_signal(captured_signal)
#   File "/usr/lib/python3.12/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/starlette/routing.py", line 701, in lifespan
#     await receive()
#   File "/usr/local/lib/python3.12/dist-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/queues.py", line 158, in get
#     await getter
# asyncio.exceptions.CancelledError
#
# ^C
