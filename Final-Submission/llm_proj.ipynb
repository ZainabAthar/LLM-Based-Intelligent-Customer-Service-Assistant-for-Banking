# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/final-version
# Out:
# /content/drive/.shortcut-targets-by-id/1teAeS1cWYOr1XbtMgu_wXO4Zl__2GFLx/final-version

# %%
# !pip install -q transformers peft trl bitsandbytes datasets accelerate chromadb sentence-transformers openpyxl
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.8/630.8 kB 26.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 38.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.6/21.6 MB 66.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 69.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 71.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.0/142.0 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 kB 23.5 MB/s eta 0:00:00
# ...

# %%
# !python extract_rate_sheet_jsonl.py
# !python preprocessing_new.py
# Out:
# Reading Excel Sheet Index 1...
# SUCCESS: Extracted 36 records to preprocessed_data/rate_sheet_only.jsonl
# Skipping:    Main
# Skipping:    Rate Sheet July 1 2024
# Processing:  LCA                  → Little Champs Account
#   → 6 records
# Processing:  NAA                  → NUST Asaan Account
#   → 5 records
# Processing:  NWA                  → NUST Waqaar Account
#   → 5 records
# Processing:  PWRA                 → PakWatan Remittance Account
#   → 7 records
# Processing:  RDA                  → Roshan Digital Account
#   → 7 records
# Processing:  VPCA                 → Value Plus Current Account
#   → 4 records
# Processing:  VP-BA                → Value Plus Business Account
#   → 5 records
# Processing:  VPBA                 → NUST Value Premium Business Account
#   → 5 records
# Processing:  NSDA                 → NUST Special Deposit Account
#   → 5 records
# Processing:  PLS                  → Profit and Loss Sharing Account
#   → 4 records
# ...

# %%
# !python vector_db_setup.py
# Out:
# 📥 Loading embedding model: all-MiniLM-L6-v2...
# ...
# modules.json: 100% 349/349 [00:00<00:00, 1.98MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 718kB/s]
# README.md: 10.5kB [00:00, 31.1MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 327kB/s]
# config.json: 100% 612/612 [00:00<00:00, 3.97MB/s]
# model.safetensors: 100% 90.9M/90.9M [00:01<00:00, 83.2MB/s]
# Loading weights: 100% 103/103 [00:00<00:00, 1906.36it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json: 100% 350/350 [00:00<00:00, 1.72MB/s]
# vocab.txt: 232kB [00:00, 21.8MB/s]
# tokenizer.json: 466kB [00:00, 57.0MB/s]
# ...

# %%
# !pip install -U transformers accelerate peft

# %%
# !python finetune.py
# Out:
# GPU:  Tesla T4
# VRAM: 15.6 GB
# Loading data...
# Loaded 350 samples
# Map: 100% 350/350 [00:01<00:00, 311.08 examples/s]
# Loading model...
# Loading weights: 100% 434/434 [00:06<00:00, 67.13it/s]
# trainable params: 3,686,400 || all params: 3,089,072,128 || trainable%: 0.1193
# Starting training...
# {'loss': '3.796', 'grad_norm': '0.1146', 'learning_rate': '0.00017', 'epoch': '0.5079'}
# {'loss': '2.448', 'grad_norm': '0.05903', 'learning_rate': '0.0001367', 'epoch': '1'}
#  33% 20/60 [05:36<10:14, 15.36s/it]/usr/local/lib/python3.12/dist-packages/peft/utils/save_and_load.py:309: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# {'loss': '2.158', 'grad_norm': '0.05585', 'learning_rate': '0.0001033', 'epoch': '1.508'}
# {'loss': '2.08', 'grad_norm': '0.07475', 'learning_rate': '7e-05', 'epoch': '2'}
# ...

# %%
# !pip install fastapi uvicorn pyngrok

# %%
# !python api_service.py --token 3Bnzldsllzo22ZLaMrgUFo5xRdB_41DMsF8Ab3cZJgtKJZMjX
# Out:
# ...
# PUBLIC ENDPOINT:
# https://unsplendidly-postethmoid-tiffiny.ngrok-free.dev
# ...
#
# INFO:     Started server process [24559]
# INFO:     Waiting for application startup.
# Starting NUST Bank AI API...
# Initializing NUST Bank RAG Assistant...
#   Base model : Qwen/Qwen2.5-3B-Instruct
#   LoRA path  : /content/drive/.shortcut-targets-by-id/1teAeS1cWYOr1XbtMgu_wXO4Zl__2GFLx/final-version/lora_bank_model_qwenx
#   DB dir     : /content/drive/.shortcut-targets-by-id/1teAeS1cWYOr1XbtMgu_wXO4Zl__2GFLx/final-version/vector_store_new
#   Tokenizer loaded from LoRA directory.
#   Loading base model...
# ...
# Loading weights:  17% 75/434 [00:06<00:16, 21.84it/s]t=2026-04-05T14:32:52+0000 lvl=warn msg="failed to open private leg" id=9d0cb17845f2 privaddr=localhost:8000 err="dial tcp [::1]:8000: connect: connection refused"
# Loading weights: 100% 434/434 [00:22<00:00, 19.66it/s]
#   Applying LoRA adapter...
#   LoRA adapter applied.
#   Vector DB: 335 records loaded.
# ...

# %%
# !python api_service.py --token 3Bnzldsllzo22ZLaMrgUFo5xRdB_41DMsF8Ab3cZJgtKJZMjX
# Out:
# ...
# PUBLIC ENDPOINT:
# https://unsplendidly-postethmoid-tiffiny.ngrok-free.dev
# ...
#
# INFO:     Started server process [39289]
# INFO:     Waiting for application startup.
# Starting NUST Bank AI API...
# Initializing NUST Bank RAG Assistant...
#   Base model : Qwen/Qwen2.5-3B-Instruct
#   LoRA path  : /content/drive/.shortcut-targets-by-id/1teAeS1cWYOr1XbtMgu_wXO4Zl__2GFLx/final-version/lora_bank_model_qwenx
#   DB dir     : /content/drive/.shortcut-targets-by-id/1teAeS1cWYOr1XbtMgu_wXO4Zl__2GFLx/final-version/vector_store_new
#   Tokenizer loaded from LoRA directory.
#   Loading base model...
# Loading weights: 100% 434/434 [00:22<00:00, 19.00it/s]
#   Applying LoRA adapter...
#   LoRA adapter applied.
#   Vector DB: 334 records loaded.
# ...
# Loading weights: 100% 103/103 [00:00<00:00, 4451.77it/s]
# Loading weights: 100% 105/105 [00:00<00:00, 805.00it/s]
#
# System Ready! Type your question.
#
# API ready.
# INFO:     Application startup complete.
# ...
